# %%
from pygraphblas import *
from pygraphblas.gviz import *

prob = dict(Matrix.ssget('FIDAP/ex33'))
M = prob['ex33.mtx']
draw_matrix(M, scale=2, cmap='plasma')
# Out:
# <PIL.Image.Image image mode=RGB size=3469x3469 at 0x7FF99D1A7A00>

# %%
draw_graph(M.triu(1), show_weight=False, labels=False, edge_cmap='plasma',
           node_attr=dict(shape='point'), 
           edge_attr=dict(arrowhead='none'), 
           graph_attr=dict(layout='neato'))
