# %%
from pygraphblas import *
from pygraphblas.gviz import *

M = dict(Matrix.ssget('Newman/karate'))['karate.mtx']
draw_matrix(M, scale=20, cmap='plasma', labels=False)
# Out:
# <PIL.Image.Image image mode=RGB size=701x701 at 0x7FB9184A1640>

# %%
draw(M, show_weight=False, directed=False, graph_attr=dict(layout='sfdp'))
