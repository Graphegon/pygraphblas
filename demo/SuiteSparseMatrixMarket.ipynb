# %%
from pygraphblas import *
from pygraphblas.gviz import *

prob = dict(Matrix.ssget('Gset/G13'))
draw_matrix(prob['G13.mtx'], scale=1)
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=802x802 at 0x7FB1ECE61D60>

# %%
draw_graph(prob['G13.mtx'], show_weight=False, labels=False, node_attr=dict(shape='point'), edge_attr=dict(arrowhead='none'), 
           graph_attr=dict(layout='neato'))
