# %% [markdown]
# # User Defined Types
#
# User Defined Types (UDT) allow you to define a custom Matrix element type.  For example in the shortest path problem, it can be useful to calculate not just the path length, but the number of hops along the shortest path, and a tree of shortest paths from every node back to the source.  This example is a high level translate of the `LAGraph_BF_full` function implementing the [Bellman-Ford algorithm](https://en.wikipedia.org/wiki/Bellman%E2%80%93Ford_algorithm)

# %%
from pygraphblas import *
from pygraphblas import lib
from pygraphblas.types import Type, binop
import numpy as np

UINT64_MAX = np.iinfo(np.uint64).max

class BF(Type):
    
    _base_name = "UDT"
    _numpy_t = None
    members = ['double w', 'uint64_t h', 'uint64_t pi']
    one = (float('inf'), UINT64_MAX, UINT64_MAX)
    
    @binop(boolean=True) 
    def EQ(z, x, y):
        if not x.w == y.w and x.h == y.h and x.pi == y.pi:
            z = True
        else:
            z = False

    @binop()
    def PLUS(z, x, y):
        if (x.w < y.w 
            or x.w == y.w and x.h < y.h 
            or x.w == y.w and x.h == y.h and x.pi < y.pi):
            if (z.w != x.w and z.h != x.h and z.pi != x.pi):
                z.w = x.w
                z.h = x.h
                z.pi = x.pi        
        else:
            z.w = y.w
            z.h = y.h
            z.pi = y.pi   

    @binop()
    def TIMES(z, x, y):
        z.w = x.w + y.w
        z.h = x.h + y.h
        if x.pi != UINT64_MAX and y.pi != 0:
            z.pi = y.pi
        else:
            z.pi = x.pi

# %%
BF_monoid = BF.new_monoid(BF.PLUS, BF.one)
BF_semiring = BF.new_semiring(BF_monoid, BF.TIMES)

def shortest_path(matrix, start):
    n = matrix.nrows
    v = Vector.sparse(matrix.type, n)
    for i, j, k in matrix:
        if i == j:
            matrix[i,j] = (0, 0, 0)
        else:
            matrix[i,j] = (k[0], 1, i)        
    v[start] = (0, 0, 0)
    with BF_semiring, Accum(BF.PLUS):
        for _ in range(matrix.nrows):
            w = v.dup()
            v @= matrix
            if w.iseq(v):
                break
    return v

A = Matrix.sparse(BF, 6, 6)
A[0,1] = (9.0, 0, 0)
A[0,3] = (3.0, 0, 0)
A[1,2] = (8.0, 0, 0)
A[3,4] = (6.0, 0, 0)
A[3,5] = (1.0, 0, 0)
A[4,2] = (4.0, 0, 0)
A[1,5] = (7.0, 0, 0)
A[5,4] = (2.0, 0, 0)

# %%
from pygraphblas.gviz import draw
draw(A)

# %% [markdown]
# ## Computing the shortest path
#
# Below is the result of labeling each node with the result of the shortest path computation.  Each result is a tuple, the first value is the accumulated weight from the starting node.  The second value is the number of hops from the starting node.  The third value is the node "back" to the starting node, forming a shortest path tree with the starting node as the root.

# %%
draw(A, label_vector=shortest_path(A, 0))
# Out:
# ---------------------------------------------------------------------------
# DomainMismatch                            Traceback (most recent call last)
# /tmp/ipykernel_22282/4057103135.py in <module>
# ----> 1 draw(A, label_vector=shortest_path(A, 0))
#
# /tmp/ipykernel_22282/349998814.py in shortest_path(matrix, start)
#      15             w = v.dup()
#      16             v @= matrix
# ---> 17             if w.iseq(v):
#      18                 break
#      19     return v
#
# ~/dev/pygraphblas/pygraphblas/vector.py in iseq(self, other, eq_op)
#     189         if self.type != other.type:
#     190             return False
# --> 191         return self.all(other, self.type.EQ)
#     192
#     193     def isne(self, other):
#
# ~/dev/pygraphblas/pygraphblas/vector.py in all(self, other, op)
#     164         if self.nvals != other.nvals:
#     165             return False
# --> 166         C = self.emult(other, op, cast=types.BOOL)
#     167         if C.nvals != self.nvals:  # pragma: nocover
#     168             return False
#
# ~/dev/pygraphblas/pygraphblas/vector.py in emult(self, other, mult_op, cast, out, mask, accum, desc)
#     682
#     683         mult_op = mult_op.get_binaryop(self.type, other.type)
# --> 684         self._check(
#     685             lib.GrB_Vector_eWiseMult_BinaryOp(
#     686                 out._vector[0],
#
# ~/dev/pygraphblas/pygraphblas/vector.py in _check(self, res)
#      77             error_string = ffi.new("char**")
#      78             lib.GrB_Vector_error(error_string, self._vector[0])
# ---> 79             raise _error_codes[res](ffi.string(error_string[0]))
#      80
#      81     def __init__(self, vec, typ=None):
#
# DomainMismatch: b''
