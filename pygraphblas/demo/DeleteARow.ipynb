# %%
from pygraphblas import *

# %%
mask = Vector.dense(BOOL, 300)
A = Matrix.from_random(UINT8, 300, 300, 9000, seed=42)
Mask = Matrix.from_type(BOOL, 300, 300)
Mask[1,:] = mask

# %%
# %%timeit
B = A.dup()
B.apply(identity, mask=Mask, out=B, desc=descriptor.oocr)
# Out:
# 88.6 µs ± 1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
B = A.dup()
B.extract_matrix(mask=Mask, out=B, desc=descriptor.oocr)
# Out:
# 429 µs ± 56.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
